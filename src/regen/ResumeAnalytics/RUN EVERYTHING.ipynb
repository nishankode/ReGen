# %%
from ResumeValidator import ValidateResume
from jobDescriptionScraper import LinkedInDescriptionScraper

# %%
linkedIndescriptionCollector = LinkedInDescriptionScraper()

# %%
# job_url = "https://www.linkedin.com/jobs/search/?currentJobId=3856391848&geoId=105214831&keywords=Data%20Scientist&location=Bengaluru%2C%20Karnataka%2C%20India&origin=JOB_SEARCH_PAGE_SEARCH_BUTTON&refresh=true"


job_id = 3686543554
job_description = linkedIndescriptionCollector.getDescription(job_id=job_id)

# %%
print(job_description)
# Out:
# Description
#
# Working at West means having an opportunity to work by the side of our patients and customers, our global team members and the communities in which we operate – which all help contribute to a Healthier World.
#
# ...

# %%
resume = """Data Scientist with 3 years of industrial work experience in Machine Learning and Generative AI. I possess a
solid foundation in Python programming, Machine Learning, and working with various LLM’s and Generative AI
Technologies. I have led teams to develop innovative solutions, optimize workflows for performance, and contribute to the advancement of AI technologies. I specialize in building closed-source commercial products leveraging Generative AI to improve people's lives. Although I lack a formal Computer Science background, my practical experience has honed my skills.
DATA SCIENTIST
+91 6238636870 · mdnishan006@gmail.com · Kollam, Kerala, India, 690518
N Muhammed Nishan
MSM College, Alappuzha, Kerala 2018-2021
SKILLS
Generative AI, LangChain, LLM’s, Machine Learning, Python, HTML, Prompt Engineering, Statistics, Distributed Computing, NLP, CUDA/cuDNN, TensorFlow.
EDUCATION
B.Sc in Physics, MSM College, Alappuzha, Kerala, 2018-2021
PROFESSIONAL EXPERIENCE
Data Scientist, Logicplum
AI Cloud - Automated ML Modelling: Led a team of Data Scientists in developing a platform to reduce human intervention in building ML Models.
Incorporated Open AI GPT-4 for intelligent ML decisions.
Created pipelines to automate the Modelling Workflow.
Implemented advanced monitoring and alerting systems for real-time performance tracking.
Fostered a culture of continuous learning and improvement within the team.
June 2022 - Present (3 Years)
AI For Alignment Chain: Developed a platform to automate requirement gathering and product feature generation tasks.
Deployed a comprehensive LLM Application with Langchain, LLama Index, OpenAI, Mistral 7b, Ollama.
Automated identification of potential clashes in client requirements using historical data.
Utilized Langchain Architecture for end-to-end Workflow with Vector Databases.
Aided PM’s in reducing workload by 30%.
PERSONAL PROJECTS (OPEN & CLOSED)
AI Assisted Instagram Reel Generator Platform: Spearheaded the development of an AI Assisted Instagram Reel Generator powered by Google Gemini LLM.
ReGen - Job Search and Resume Generator: Developed an AI-based platform to tailor resumes for specific job descriptions.
Webby- Chat with websites: Developed an AI-based chatbot utilizing Open AI API.
Multi Document Chatbot: Developed a Langchain-powered AI chatbot for processing multiple documents.
Github : https://github.com/nishan0000"""

# %%
resume_score_validator = ValidateResume()
scores = resume_score_validator.get_resume_scores(resume, job_description)

# %%
scores
# Out:
# {'Keyword_Matching_Score': '75',
#  'Skills_Matching_Score': '85',
#  'Qualifications_Matching_Score': '70',
#  'Experience_Alignment_Score': '80',
#  'Education_and_Certifications_Alignment_Score': '60',
#  'Soft_Skills_and_Personal_Attributes_Score': '75',
#  'Overall_Fit_Score': '77'}

# %%
scores = {'Keyword_Matching_Score': '75',
 'Skills_Matching_Score': '85',
 'Qualifications_Matching_Score': '70',
 'Experience_Alignment_Score': '80',
 'Education_and_Certifications_Alignment_Score': '60',
 'Soft_Skills_and_Personal_Attributes_Score': '75',
 'Overall_Fit_Score': '77'}

# %%
prompt = f"""
You are an experienced Resume rewriting professional. I will provide you 3 things.

1. Old Resume Content of a job aspirant - old_resume : {resume}.
2. A job description, to which the aspirant is applying - job_description : {job_description}.
3. A JSON of scores, which gives a great idea of how relavant the job aspirant is for the job description. The description 
   and how the scores are calculated is given below - old_scores: {scores}.


Score Calculation Methodology:
[Keyword Matching Score :
[LLM Identifies the keywords and phrases in the job description that reflect required skills, qualifications, and experiences. Then, 
count how many of these keywords appear in the candidate's resume and calculate the percentage of matched keywords to calculate the score 
between 1 and 100, both inclusive.]

Skills Matching Score :
[LLM closely examines the skills and qualifications listed in the job description, Check if the candidate's resume includes evidence of 
possessing these skills and qualifications. Then, assign weights to skills based on their importance to the job role and calculate a weighted 
percentage of matched skills and qualifications between 1 and 100, both inclusive.]

Qualifications Matching Score :
[LLM Closely examine the qualifications listed in the job description, Check if the candidate's resume includes evidence of possessing these 
qualifications. Then, assign weights to qualifications based on their importance to the job role and calculate a weighted percentage of matched 
qualifications to calculate the score between 1 and 100, both inclusive.]

Experience Alignment Score :
[LLM Analyze the candidate's work experience as presented in the resume, Compare the candidate's past roles, responsibilities, and achievements 
with those outlined in the job description, Assess the relevance and depth of experience. Finally, Quantify the alignment between the candidate's 
experience and the job requirements to calculate the score between 1 and 100, both inclusive.]

Education and Certifications Alignment Score :
[LLM Verifies if the candidate's educational background and certifications meet the requirements specified in the job description, Consider the 
relevance of the candidate's academic achievements to the role, Assign weights to education and certifications based on their importance to the 
job. Finally, calculate a weighted percentage of educational and certification match. The percentage should be between 1 and 100, both inclusive.]

Soft Skills and Personal Attributes Score :
[LLM evaluate if the candidate's soft skills and personal attributes align with the job requirements, Look for evidence of communication skills, 
teamwork, leadership, adaptability, etc. Assess cultural fit based on the company's values and work environment. This can be more subjective but 
can still be quantified based on explicit mentions in the resume. Finally calculate the score, and the score should be between 1 and 100, both inclusive.]

Overall Fit Score :
[LLM combine the results from the above metrics, assigning weights to each based on their importance. Sum up the weighted scores to obtain an 
overall fit score. Normalize the score to a percentage scale (e.g., out of 100).]]


- After analyzing all the input datas, (old_resume, job_description and old_scores), your job is to generate a new resume by improving the scores, 
which ensures maximum possibility to be selected by the recruiter for the given input job. You are not allowed to add un-necessary information to 
the newly generated resume. Generate only what's relavant.


- The output should be a well defined and structured HTML, as a string. The preferred Template structure is given below.

Template
--------

NAME <Middle of the page>
phone . mailid . address 

PERSONAL DESCRIPTION <Middle of the page> 
Description Content <Left Aligned>

PROFESSIONAL EXPERIENCE <Middle of the page> - If any
Company 1 Name (Bold) <left end>            StartMonth - StartYear (total time period) <right end>
Project Name (Bold) - Project Description in 1 sentence  <Left Aligned>
 - What have been done 1 <Left Aligned>
 - What have been done 2 <Left Aligned>
 .
 .
 - What have been done n <Left Aligned>

Company 2 Name (If available) (Bold)<left end>            StartMonth - StartYear (total time period) <right end>
Project Name (Bold) - Project Description in 1 sentence
 - What have been done 1 <Left Aligned>
 - What have been done 2 <Left Aligned>
 .
 .
 - What have been done n <Left Aligned>

PERSONAL PRODUCTS <Middle of the page> - If any
Github Link - if available <Middle of the page>
Project 1 Name (Bold) <Left Aligned> : Project 1 Description in 2 sentence. <Left Aligned>
Project 2 Name (Bold) <Left Aligned> : Project 2 Description in 2 sentence. <Left Aligned>
Project 3 Name (Bold) <Left Aligned> : Project 3 Description in 2 sentence. <Left Aligned>

SKILLS <Middle of the page>
Skill-1, Skill-2, skill-3 ..........., skill-n  <Left Aligned>

EDUCATION
Institution 1 Name <left end> <Left Aligned>              Start Year - End Year <Right end> 
Subject
Institution 2 Name (If available) <left end> <Left Aligned>               Start Year - End Year <Right end>
Subject <Left Aligned>

"""

# %%
print(prompt)
# Out:
# You are an experienced Resume rewriting professional. I will provide you 3 things.
#
# 1. Old Resume Content of a job aspirant - old_resume : Data Scientist with 3 years of industrial work experience in Machine Learning and Generative AI. I possess a
# solid foundation in Python programming, Machine Learning, and working with various LLM’s and Generative AI
# Technologies. I have led teams to develop innovative solutions, optimize workflows for performance, and contribute to the advancement of AI technologies. I specialize in building closed-source commercial products leveraging Generative AI to improve people's lives. Although I lack a formal Computer Science background, my practical experience has honed my skills.
# DATA SCIENTIST
# +91 6238636870 · mdnishan006@gmail.com · Kollam, Kerala, India, 690518
# N Muhammed Nishan
# MSM College, Alappuzha, Kerala 2018-2021
# SKILLS
# ...

# %% [markdown]
# # HTML PDF

# %%
import jinja2
import pdfkit

# %%
# Your data dictionary
data_scientist_info = {
    "name": "N Muhammed Nishan",
    "contact": {
        "phone": "+91 6238636870",
        "email": "mdnishan006@gmail.com",
        "location": "Kollam, Kerala, India, 690518"
    },
    
    "education": [{
        "university": "MSM College, Alappuzha, Kerala",
        "years": "2018-2021",
        "CGPA" : "5.6"},
        {"university": "SBCS, Karunagappally, Kerala",
        "years": "2018-2021",
        "CGPA" : "8.8"}],

    "skills": [
        "Generative AI",
        "LangChain",
        "LLM’s",
        "Machine Learning",
        "Python",
        "HTML",
        "Prompt Engineering",
        "Statistics"
    ],
    "professional_experience": [
        {
            "company": "Logicplum",
            "position": "Data Scientist",
            "projects": [
                {
                    "name": "AI Cloud - Automated ML Modelling",
                    "description": "A platform which helps reduce human intervention while building ML Models.",
                    "responsibilities": [
                        "Guided a team of Data Scientists in product development.",
                        "Incorporated Open AI GPT-4 for intelligent ML decisions.",
                        "Created pipelines to automate the Modelling Workflow.",
                        "Implemented advanced monitoring and alerting systems.",
                        "Fostered a culture of continuous learning and improvement."
                    ],
                    "duration": "June 2022 - Present (1 Year 9 Months)"
                },
                {
                    "name": "AI For Alignment Chain",
                    "description": "A platform which helps project managers to automate the process of requirement gathering, Product feature generation and many other tasks.",
                    "responsibilities": [
                        "Deployed a comprehensive LLM Application with Langchain, LLama Index, OpenAI, Mistral 7b, Ollama.",
                        "Automated identification of potential clashes in client requirements using historical data.",
                        "Utilized Langchain Architecture for end-to-end Workflow with Vector Databases.",
                        "Aided PM’s in cutting workload by 30% through minimizing meetings, inquiries, emails.",
                        "Employed strategies to minimize API Calls to OpenAI, lowering development expenses."
                    ],
                    "duration": "June 2022 - Present (1 Year 9 Months)"
                }
            ]
        },
        {
            "company": "Luminar Technolab",
            "position": "Data Science Intern",
            "projects": [
                {
                    "name": "Various Data Science Projects",
                    "description": "Worked on projects involving ML, DL, NLP, etc.",
                    "responsibilities": [
                        "Gained hands-on experience in machine learning, deep learning, and natural language processing.",
                        "Contributed to various data science projects within the company.",
                        "Learned and implemented various algorithms and techniques."
                    ],
                    "duration": "August 2021 - June 2022"
                }
            ]
        }
    ],
    "personal_projects": [
        {
            "name": "AI Assisted Instagram Reel Generator Platform",
            "description": "An AI Assisted Instagram Reel Generator powered by Google Gemini LLM, streamlining the creation process with minimal human intervention through automated caption, description, and hashtag generation."
        },
        {
            "name": "ReGen - Job Search and Resume Generator",
            "description": "An AI Based platform which takes any resume as input, Search for most favourable jobs in LinkedIn, Naukri, Indeed, regenerates resume for that particular job description. This is an ongoing development."
        },
        {
            "name": "Webby- Chat with websites",
            "description": "Webby is an AI Based chatbot which utilizes Open AI API to make the conversation with websites possible. Utilizes lang chain for the development process."
        },
        {
            "name": "Multi Document Chatbot",
            "description": "Langchain-powered AI chatbot processes multiple documents for accurate, context-rich responses, enabling seamless interactions and comprehensive answers."
        }
    ],

    "github": "https://github.com/nishan0000",

    "achievements": [
    "Iron Pillar award - For the best team of the company",
    "Best Performer Award - For Q3 2023"]
}

# %%
import pdfkit


# Options for PDF conversion (optional)
options = {
    'page-size': 'A4',
    'margin-top': '0.75in',
    'margin-right': '0.75in',
    'margin-bottom': '0.75in',
    'margin-left': '0.75in',
    'encoding': "UTF-8",
    'no-outline': None
}

# Convert HTML to PDF
pdfkit.from_file('res.html', 'output_pdf.pdf', options=options)

print("PDF created successfully!")
# Out:
# PDF created successfully!

# %%
# Load the template
template_loader = jinja2.FileSystemLoader(searchpath="./")

# %%
template_env = jinja2.Environment(loader=template_loader)

# %%
template = template_env.get_template("resume_template.html")

# %%
# Render the template with the data
rendered_template = template.render(data_scientist_info=data_scientist_info)

# %%
import pdfkit

# Specify the path to the wkhtmltopdf executable
config = pdfkit.configuration(wkhtmltopdf='C:/Program Files/wkhtmltopdf/bin/wkhtmltopdf.exe')

# Convert HTML to PDF using the specified configuration
pdfkit.from_string(rendered_template, 'resume.pdf', configuration=config)
# Out:
# True
