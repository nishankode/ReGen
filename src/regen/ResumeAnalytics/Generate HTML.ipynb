# %%
import jinja2
import pdfkit

# %%
# Your data dictionary
data_scientist_info = {
    "name": "N Muhammed Nishan",
    "profession_name" : "DATA SCIENTIST",
    "description" : "Data Scientist with 2 years of industrial work experience in Machine Learning and Generative AI. I possess a strong foundation in Python programming, Machine Learning, working with different LLM’s, Generative AI Technologies. I have collaborated with different teams to develop innovative solutions, optimize workflow for performance, and contribute to the advancement of AI technologies in my company. I build closed source commercial products, which leverage Generative AI to help make peoples life easier. No Computer Science Academic Background",
    "contact": {
        "phone": "+91 6238636870",
        "email": "mdnishan006@gmail.com",
        "location": "Kollam, Kerala, India, 690518"
    },
    
    "education": [{
        "institution": "MSM College, Alappuzha, Kerala",
        "years": "2018-2021",
        "subject": "Physics",
        "CGPA" : "5.6"},
        {"institution": "SBCS, Karunagappally, Kerala",
        "years": "2015-2018",
        "subject": "PCMB",
        "CGPA" : "8.8"}],

    "skills": "Generative AI, LangChain, LLM’s, Machine Learning, Python, HTML, Prompt Engineering, Statistics",
    "professional_experience": [
        {
            "company": "Logicplum",
            "position": "Data Scientist",
            "duration": "June 2022 - Present (1 Year 9 Months)",
            "projects": [
                {
                    "name": "AI Cloud - Automated ML Modelling",
                    "description": "A platform which helps reduce human intervention while building ML Models.",
                    "responsibilities": [
                        "Guided a team of Data Scientists in product development.",
                        "Incorporated Open AI GPT-4 for intelligent ML decisions.",
                        "Created pipelines to automate the Modelling Workflow.",
                        "Implemented advanced monitoring and alerting systems.",
                        "Fostered a culture of continuous learning and improvement."
                    ]
                },
                {
                    "name": "AI For Alignment Chain",
                    "description": "A platform which helps project managers to automate the process of requirement gathering, Product feature generation and many other tasks.",
                    "responsibilities": [
                        "Deployed a comprehensive LLM Application with Langchain, LLama Index, OpenAI, Mistral 7b, Ollama.",
                        "Automated identification of potential clashes in client requirements using historical data.",
                        "Utilized Langchain Architecture for end-to-end Workflow with Vector Databases.",
                        "Aided PM’s in cutting workload by 30% through minimizing meetings, inquiries, emails.",
                        "Employed strategies to minimize API Calls to OpenAI, lowering development expenses."
                    ]
                }
            ]
        },
        {
            "company": "Luminar Technolab",
            "position": "Data Science Intern",
            "duration": "August 2021 - June 2022 (10 Months)",
            "projects": [
                {
                    "name": "Various Data Science Projects",
                    "description": "Worked on projects involving ML, DL, NLP, etc.",
                    "responsibilities": [
                        "Gained hands-on experience in machine learning, deep learning, and natural language processing.",
                        "Contributed to various data science projects within the company.",
                        "Learned and implemented various algorithms and techniques."
                    ]
                }
            ]
        }
    ],
    "personal_projects": [
        {
            "name": "AI Assisted Instagram Reel Generator Platform",
            "description": "An AI Assisted Instagram Reel Generator powered by Google Gemini LLM, streamlining the creation process with minimal human intervention through automated caption, description, and hashtag generation."
        },
        {
            "name": "ReGen - Job Search and Resume Generator",
            "description": "An AI Based platform which takes any resume as input, Search for most favourable jobs in LinkedIn, Naukri, Indeed, regenerates resume for that particular job description. This is an ongoing development."
        },
        {
            "name": "Webby- Chat with websites",
            "description": "Webby is an AI Based chatbot which utilizes Open AI API to make the conversation with websites possible. Utilizes lang chain for the development process."
        },
        {
            "name": "Multi Document Chatbot",
            "description": "Langchain-powered AI chatbot processes multiple documents for accurate, context-rich responses, enabling seamless interactions and comprehensive answers."
        }
    ],
    "github": "https://github.com/nishan0000",
    "achievements": [
    "Iron Pillar award - For the best team of the company",
    "Best Performer Award - For Q3 2023"]
}

# %%
data_scientist_info = {
  "name": "Maria Ivanova",
  "profession_name": "Data Analyst",
  "description": "Maria Ivanova is a skilled data analyst with a passion for extracting actionable insights from complex datasets. With a strong background in statistics and data visualization, she specializes in transforming raw data into meaningful reports and presentations that drive business decision-making. Maria is adept at using various analytical tools and techniques to solve problems and optimize processes for organizations.",
  "contact": {
    "phone": "+7 XXX XXX XX XX",
    "email": "maria.ivanova@example.com",
    "location": "Saint Petersburg, Russia"
  },
  "education": [
    {
      "institution": "Saint Petersburg State University",
      "years": "2014-2018",
      "subject": "Applied Mathematics",
      "degree": "Bachelor of Science"
    },
    {
      "institution": "Higher School of Economics",
      "years": "2018-2020",
      "subject": "Data Analysis",
      "degree": "Master of Science"
    }
  ],
  "skills": "Data Analysis, Statistical Analysis, Data Visualization, SQL, Python, Excel, Tableau",
  "professional_experience": [
    {
      "company": "Tech Solutions Ltd.",
      "position": "Data Analyst",
      "duration": "July 2020 - Present",
      "projects": [
        {
          "name": "Sales Performance Analysis",
          "description": "Conducted in-depth analysis of sales data to identify trends, patterns, and opportunities for improvement.",
          "responsibilities": [
            "Developed SQL queries to extract and manipulate data from databases.",
            "Created interactive dashboards in Tableau to visualize key metrics and KPIs.",
            "Generated regular reports to provide insights to stakeholders and support decision-making."
          ]
        },
        {
          "name": "Customer Segmentation",
          "description": "Segmented customers based on behavior and demographics to tailor marketing strategies and improve customer experience.",
          "responsibilities": [
            "Performed clustering analysis using Python and scikit-learn.",
            "Collaborated with marketing teams to implement targeted campaigns.",
            "Evaluated campaign effectiveness and made recommendations for optimization."
          ]
        }
      ]
    }
  ],
  "personal_projects": [
    {
      "name": "Data Visualization Blog",
      "description": "Created a blog showcasing various data visualization techniques and best practices."
    },
    {
      "name": "Predictive Analytics Model",
      "description": "Developed a predictive model to forecast sales based on historical data."
    }
  ],
  "github": "https://www.linkedin.com/in/maria-ivanova",
  "certifications": [
    "Data Analyst Nanodegree - Udacity",
    "Tableau Desktop Specialist Certification"
  ]
}

# %%
template_loader = jinja2.FileSystemLoader(searchpath="./")
template_env = jinja2.Environment(loader=template_loader)
template = template_env.get_template("resume_template.html")
rendered_template = template.render(data_scientist_info=data_scientist_info)

# %%
config = pdfkit.configuration(wkhtmltopdf='C:/Program Files/wkhtmltopdf/bin/wkhtmltopdf.exe')

# Options for PDF conversion (optional)
options = {
    'page-size': 'A4',
    'margin-top': '0.3in',
    'margin-right': '0.5in',
    'margin-bottom': '0.3in',
    'margin-left': '0.5in',
    'encoding': "UTF-8",
    'no-outline': None
}

pdfkit.from_string(rendered_template
                   , 'Generated Resume.pdf'
                   , configuration = config
                   , options = options)
# Out:
# True
